# %% [markdown]
# <center>
# <h1>Div, Grad, Curl, and All That: An Informal Text on Vector Calculus 4e</h1>
#
# <h2>Chapter 1 Solutions</h2>
# <h5>Book Author: H. M. Schey</h5>
# <h5>Solution Author: Dylan Murphy-Mancini</h5>
# </center>

# %%
# %matplotlib inline
from numpy import *
import numpy as np
import matplotlib.pyplot as plt

# %%
# Gloabal Variables
_FIGSIZE = (11,11) #<<< size demensions of graph (x,y)

# %% [markdown]
# ## I-1
#
# >Using arrows of proper magnitude and direction, sketch each of the followng vector functions:
#
#
# (a)  $\textbf{i}y + \textbf{j}x$
#
# (b)  $(\textbf{i} + \textbf{j})/\sqrt{2}$
#
# (a)  $\textbf{i}x + \textbf{j}y$
#
# (d)  $\textbf{i}y$
#
# (e)  $\textbf{j}x$
#
# (f)  $\textbf{i}y + \textbf{j}x$
#
# (g)  $\textbf{i}y + \textbf{j}x$
#
# (h)  $\textbf{i}y + \textbf{j}x$

# %%
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords
ones = np.ones((20, 20))
vx= yy
vy= xx


fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=50, angles='xy')
plt.show()

# %%
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords
vx= yy
vy= xx

fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=200, angles='xy')
plt.show()

# %%
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords
vx= sqrt(2)
vy= sqrt(2)

fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=50, angles='xy')
plt.show()

# %%
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords
vx= xx
vy= -yy

fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=50, angles='xy')
plt.show()

# %%
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords
vx= yy
vy= 0*yy

fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=150, angles='xy')
plt.show()

# %%
import numpy
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords

vx= np.ones((20, 20))
vy= yy

fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=100, angles='xy')
plt.show()

# %%
import numpy
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords

vx= np.ones((20, 20))
vy= yy

fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=100, angles='xy')
plt.show()

# %%
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords
vx= yy*0
vy= xx
fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=400, angles='xy')
plt.show()

# %%
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords

(vx, vy) = (0*xx, xx)       # create x,y components of fields (from xx, yy)

fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=400, angles='xy')
plt.show()

# %%
y = x = arange(-10,10,1)   # 1D list of coords (for vector fields, don't get too dense)
(xx,yy) = meshgrid(x,y)    # 2D arrays of coords
vx= -yy
vy= xx
fig = plt.figure(figsize=_FIGSIZE)
q = plt.quiver(xx,yy,vx,vy, 1, scale=200, angles='xy')
plt.show()
